# %%
from PIL import Image
import matplotlib.pyplot as plt

# Load the image
image_path = "low_cont.jpg"
image = Image.open(image_path)

# Convert image to grYSCALE if its a color image
if image.mode != "L":
    image=image.convert('L')

# Compute the histogram
histogram = image.histogram()

# Plot histogram in blue color
plt.figure()
plt.title("Histogram of Pixel Intensities")
plt.xlabel("Pixel Intensity")
plt.ylabel("Frequency")
plt.plot(histogram,color='blue')
plt.show()
image
# Out:
# <PIL.Image.Image image mode=L size=484x360>

# %%
# Load the image
image_path = "mona_lisa.jpg"
image = Image.open(image_path)

# Convert image to grYSCALE if its a color image
if image.mode != "L":
    image=image.convert('L')

# Compute the histogram
histogram = image.histogram()

# Plot histogram in blue color
plt.figure()
plt.title("Histogram of Pixel Intensities")
plt.xlabel("Pixel Intensity")
plt.ylabel("Frequency")
plt.plot(histogram,color='blue')
plt.show()
image
# Out:
# <PIL.Image.Image image mode=L size=677x1024>

# %%
# Load the images
image_paths = ["img1.jpg","img2.jpg","img3.jpg"]
images = [Image.open(path)for path in image_paths]

# Convert images to grayscale if they are color images
for i in range(len(images)):
    if images[i].mode !='L':
        images[i]=images[i].convert('L')

# Compute histograms
histograms=[image.histogram() for image in images]

#Plot images and their histograms
plt.figure(figsize=(15,10))

for i in range(len(images)):
    plt.subplot(2,3,i+1)
    plt.imshow(images[i],cmap='gray')
    plt.title(f'Image{i+1}')
    plt.axis('off')

    plt.subplot(2,3,i+4)
    plt.plot(histogram[i],color='blue')
    plt.title(f"Histogram{i+1}")
    plt.xlabel("Pixel intensity")
    plt.ylabel("Frequency")

plt.tight_layout()
plt.show()
